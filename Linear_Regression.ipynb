# %% [markdown]
# <a href="https://colab.research.google.com/github/shikharvishwakarma26/ML-Algorithms/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('AUDI.csv')

# %%
print(dataset)
# Out:
#     Year   Sales
# 0   2025     91.0
# 1   2024     88.3
# 2   2023     86.0
# 3   2022     81.0
# 4   2021     81.3
# 5   2020     77.6
# 6   2019     90.3
# 7   2018     95.2
# 8   2017     95.6
# 9   2016     93.9
# 10  2015     89.7
# 11  2014     87.4
# 12  2013     84.6
# 13  2012     81.2
# 14  2011     77.3
# 15  2010     74.1

# %%
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
print(x)
# Out:
# [[2025]
#  [2024]
#  [2023]
#  [2022]
#  [2021]
#  [2020]
#  [2019]
#  [2018]
#  [2017]
#  [2016]
#  [2015]
#  [2014]
#  [2013]
#  [2012]
#  [2011]
#  [2010]]

# %%
print(y)
# Out:
# [91.  88.3 86.  81.  81.3 77.6 90.3 95.2 95.6 93.9 89.7 87.4 84.6 81.2
#  77.3 74.1]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 1)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.title('year vs Sales(trainig test)')
plt.xlabel('sales')
plt.ylabel('year')
plt.show()

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.title('year vs Sales(test)')
plt.xlabel('Sales')
plt.ylabel('year')
plt.show()
